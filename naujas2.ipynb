# %%
import pandas as pd

# %%
df = pd.read_csv (r'voo_sneakers copy.csv')

# %%
print (df)
# Out:
#     Unnamed: 0         brand  \
# 0            0       Salomon
# 1            1  Hoka One One
# 2            2          Nike
# 3            3          Nike
# 4            4        Adidas
# 5            5          Nike
# 6            6   New Balance
# 7            7   New Balance
# 8            8   New Balance
# 9            9   New Balance
# 10          10   New Balance
# 11          11  Acne Studios
# 12          12  Acne Studios
# 13          13  Acne Studios
# 14          14  Acne Studios
# 15          15  Acne Studios
# 16          16          Nike
# 17          17          Nike
# 18          18   New Balance
# 19          19   New Balance
# 20          20   New Balance
# 21          21      Converse
# 22          22      Converse
# 23          23      Converse
# 24          24       Salomon
# 25          25          Nike
# 26          26          Nike
# 27          27          Nike
# 28          28   New Balance
# 29          29   New Balance
# 30          30   New Balance
# ...

# %%
list (df.columns)
# Out:
# ['Unnamed: 0', 'brand', 'model', 'price']

# %%
df.drop('Unnamed: 0', inplace=True, axis=1)

# %%
list (df.columns)
# Out:
# ['brand', 'model', 'price']

# %%
print(df)
# Out:
#            brand                                              model  \
# 0        Salomon                 \nXT-6 Advanced Sneaker in White\n
# 1   Hoka One One                   \nM Clifton 8 Sneaker in White\n
# 2           Nike      \nWMNS Air Force 1 Sculpt in White & Silver\n
# 3           Nike         \nWMNS Air Force 1 Sculpt in White & Red\n
# 4         Adidas   \nx Craig Green Scuba Phormar Sneaker in Green\n
# 5           Nike                  \nBe-do-win SP Sneaker in Black\n
# 6    New Balance           \n990 v4 'Made in USA' Sneaker in Grey\n
# 7    New Balance         \nM 990 v3 'Made in USA' Sneaker in Grey\n
# 8    New Balance    \nM 991 'Made in UK' Sneaker in Silver & Grey\n
# 9    New Balance             \nW 991 'Made in UK' Sneaker in Grey\n
# 10   New Balance   \nM 920 'Made in UK' Sneaker in Navy & Burgun...
# 11  Acne Studios               \nN3W Trail Sneaker in Matte Black\n
# 12  Acne Studios                     \nN3W Trail Sneaker in Black\n
# ...

# %%
print (df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   brand   48 non-null     object
#  1   model   48 non-null     object
#  2   price   35 non-null     object
# dtypes: object(3)
# memory usage: 1.2+ KB
# None

# %%
print (df.head(8))
# Out:
#           brand                                              model  \
# 0       Salomon                 \nXT-6 Advanced Sneaker in White\n
# 1  Hoka One One                   \nM Clifton 8 Sneaker in White\n
# 2          Nike      \nWMNS Air Force 1 Sculpt in White & Silver\n
# 3          Nike         \nWMNS Air Force 1 Sculpt in White & Red\n
# 4        Adidas   \nx Craig Green Scuba Phormar Sneaker in Green\n
# 5          Nike                  \nBe-do-win SP Sneaker in Black\n
# 6   New Balance           \n990 v4 'Made in USA' Sneaker in Grey\n
# 7   New Balance         \nM 990 v3 'Made in USA' Sneaker in Grey\n
#
#                                                price
# 0  <span class="price--default is--nowrap">\n€175...
# 1  <span class="price--default is--nowrap">\n€140...
# 2  <span class="price--default is--nowrap">\n€120...
# 3  <span class="price--default is--nowrap">\n€120...
# 4  <span class="price--default is--nowrap">\n€250...
# ...

# %%
print (df)
# Out:
#            brand                                              model  \
# 0        Salomon                 \nXT-6 Advanced Sneaker in White\n
# 1   Hoka One One                   \nM Clifton 8 Sneaker in White\n
# 2           Nike      \nWMNS Air Force 1 Sculpt in White & Silver\n
# 3           Nike         \nWMNS Air Force 1 Sculpt in White & Red\n
# 4         Adidas   \nx Craig Green Scuba Phormar Sneaker in Green\n
# 5           Nike                  \nBe-do-win SP Sneaker in Black\n
# 6    New Balance           \n990 v4 'Made in USA' Sneaker in Grey\n
# 7    New Balance         \nM 990 v3 'Made in USA' Sneaker in Grey\n
# 8    New Balance    \nM 991 'Made in UK' Sneaker in Silver & Grey\n
# 9    New Balance             \nW 991 'Made in UK' Sneaker in Grey\n
# 10   New Balance   \nM 920 'Made in UK' Sneaker in Navy & Burgun...
# 11  Acne Studios               \nN3W Trail Sneaker in Matte Black\n
# 12  Acne Studios                     \nN3W Trail Sneaker in Black\n
# ...

# %%
df['price'].to_numpy
# Out:
# <bound method IndexOpsMixin.to_numpy of 0     <span class="price--default is--nowrap">\n€175...
# 1     <span class="price--default is--nowrap">\n€140...
# 2     <span class="price--default is--nowrap">\n€120...
# 3     <span class="price--default is--nowrap">\n€120...
# 4     <span class="price--default is--nowrap">\n€250...
# 5     <span class="price--default is--nowrap">\n€130...
# 6     <span class="price--default is--nowrap">\n€250...
# 7     <span class="price--default is--nowrap">\n€220...
# 8     <span class="price--default is--nowrap">\n€190...
# 9     <span class="price--default is--nowrap">\n€190...
# 10    <span class="price--default is--nowrap">\n€220...
# 11    <span class="price--default is--nowrap">\n€340...
# 12    <span class="price--default is--nowrap">\n€340...
# 13    <span class="price--default is--nowrap">\n€420...
# 14    <span class="price--default is--nowrap">\n€420...
# 15    <span class="price--default is--nowrap">\n€340...
# ...

# %%
# price column
# numpy, slice
